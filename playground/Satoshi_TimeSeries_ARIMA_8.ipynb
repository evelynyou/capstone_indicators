# %% [markdown]
# # Stock Trading Strategy with ARIMA model

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

from statsmodels.tsa.arima_model import ARMA,ARMAResults,ARIMA,ARIMAResults
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots
from pmdarima import auto_arima # for determining ARIMA orders

import warnings
warnings.filterwarnings("ignore")

import yfinance as yf

from backtesting import Strategy, Backtest
from backtesting.lib import crossover

import time
from datetime import datetime, date
from pytz import timezone

import inspect
from typing import Tuple

# %% [markdown]
# ## Getting data and clean it up

# %%
# Getting the last 6 years data at once
def get_data(ticker):
    data = yf.download(ticker, period="6y")
    data = data.asfreq('D')
    data = data.ffill()
    return data

# %%
get_data("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-03-16  206.710007  208.690002  205.860001  208.580002  185.548767
# 2015-03-17  207.690002  208.419998  206.979996  207.960007  184.997223
# 2015-03-18  207.389999  211.270004  206.619995  210.460007  187.221176
# 2015-03-19  209.960007  210.470001  209.029999  209.500000  186.367233
# 2015-03-20  209.710007  211.020004  209.490005  210.410004  188.012238
# ...                ...         ...         ...         ...         ...
# 2021-03-12  392.070007  394.209991  391.200012  394.059998  394.059998
# 2021-03-13  392.070007  394.209991  391.200012  394.059998  394.059998
# 2021-03-14  392.070007  394.209991  391.200012  394.059998  394.059998
# 2021-03-15  392.070007  394.209991  391.200012  394.059998  394.059998
# 2021-03-16  394.329987  397.549988  396.720001  397.440002  397.440002
#
#                  Volume
# Date
# 2015-03-16  136099200.0
# 2015-03-17   94510400.0
# 2015-03-18  228808500.0
# 2015-03-19  117917300.0
# 2015-03-20  177715100.0
# ...                 ...
# 2021-03-12   64608100.0
# 2021-03-13   64608100.0
# 2021-03-14   64608100.0
# 2021-03-15   64608100.0
# 2021-03-16    4504825.0
#
# [2193 rows x 6 columns]

# %% [markdown]
# ### Making a function to predict stock price with ARIMA Model

# %%
# Making a function to create prediction of days future
# Based on given data, returning "days" future predicted price

def arima_fcst(p, q, d, data, days):
    model = ARIMA(data['Close'], order=(p,d,q))
    results = model.fit()
    fcst = results.predict(len(data),len(data)+40, dynamic=False, typ='levels')  #.rename('ARIMA Forecast') #levels, linear
    return fcst[days]

# %% [markdown]
# ### Making a for loop to run thru 10 tickers to get a one consolidated table

# %%
tickers = ['SPY', 'QQQ', 'EEM', 'AAPL', 'MSFT', 'AMZN', 'FB', 'GOOGL', 'GOOG', 'TSLA']

# %%
# Setting parameters
p = 0
d = 1
q = 3
days = 5

# %%
ARIMA_df_list = []

# %%
# Getting ARIMA signals for each ticker

for ticker in tickers:
    data = get_data(ticker)
    
    ARIMA_pred = []
    
    for n in range(len(data)-50):
        ARIMA_pred.append(arima_fcst(p, q, d, data.iloc[0+n:50+n], days))      
        
    data2 = data[50:]
    data2['ARIMA_Pred'] = ARIMA_pred
    data2['Arima_Signal'] = data2['ARIMA_Pred']/data2['Close']
    
    ARIMA_df_list.append(data2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
ARIMA_df_list[0].head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-05-05  211.029999  211.460007  208.729996  208.899994  186.662964
# 2015-05-06  209.559998  209.929993  206.759995  208.039993  185.894501
# 2015-05-07  207.919998  209.380005  207.520004  208.869995  186.636154
# 2015-05-08  210.880005  211.860001  210.779999  211.619995  189.093414
# 2015-05-09  210.880005  211.860001  210.779999  211.619995  189.093414
#
#                  Volume  ARIMA_Pred  Arima_Signal
# Date
# 2015-05-05  113326200.0  211.524341      1.012563
# 2015-05-06  135060200.0  209.470867      1.006878
# 2015-05-07   88244900.0  208.281596      0.997183
# 2015-05-08  155877300.0  208.905185      0.987171
# 2015-05-09  155877300.0  210.900720      0.996601

# %% [markdown]
# ### Defining trading strategy

# %%
def get_signal(data):
    return data['Arima_Signal']

# %%
class ARIMA_Pred(Strategy):
    low = 0.98
    high = 1.02 
    long_only = 1
    
    def init(self):
        self.signal = self.I(get_signal, self.data)
            
    def next(self):
        if self.signal > self.high:  
            if self.long_only == 0:
                self.position.close()
            self.buy()

        elif self.signal < self.low:
            self.position.close()
            if self.long_only == 0:
                self.sell()

# %% [markdown]
# ### Backtesting ARIMA strategy

# %%
# Selecting the df for the ticker

selected_ticker = "SPY"

if selected_ticker in tickers:
    index = tickers.index(selected_ticker)
else:
    print("No ARIMA model available for this ticker.")

backtest_df = ARIMA_df_list[index]

# %%
def backtest_ARIMA(ydata: pd.DataFrame, cash: int=10_000, commission: float=0.) -> Tuple[pd.DataFrame, dict]:
    temp = []
    sname_temp = []
    equity_trades = {}
    periods = ['0.5', '1', '2', 2020, 2019, 2018, 2017, 2016]
    
    for period in periods:
        if isinstance(period, str):
            data = ydata.iloc[-int(float(period)*365):]
        elif isinstance(period, int):
            data = ydata.loc["{}-12-31".format(period-1):"{}-12-31".format(period),]

        # No data
        if data.shape[0] == 0:
            continue

        bt = Backtest(data, ARIMA_Pred, cash=cash, commission=commission)
        stats = bt.run()
        sname = str(stats["_strategy"])
        sname_temp.append("{}_{}".format(sname, period))
        temp.append(stats[:27])
        equity_trades["{}_{}".format(sname, period)] = (stats["_equity_curve"], stats["_trades"])

    strat_returns = pd.concat(temp, axis=1)
    strat_returns.columns = sname_temp
    return strat_returns, equity_trades

# %%
backtest_ARIMA(backtest_df, 10_000, 0.)
# Out:
# (                             ARIMA_Pred_0.5         ARIMA_Pred_1  \
#  Start                   2020-09-16 00:00:00  2020-03-17 00:00:00
#  End                     2021-03-16 00:00:00  2021-03-16 00:00:00
#  Duration                  181 days 00:00:00    364 days 00:00:00
#  Exposure Time [%]                   70.3297              74.2466
#  Equity Final [$]                    10344.8              12245.7
#  Equity Peak [$]                     10418.1              12617.1
#  Return [%]                           3.4479              22.4568
#  Buy & Hold Return [%]               17.3012              57.2152
#  Return (Ann.) [%]                   7.03461              22.4568
#  Volatility (Ann.) [%]               14.1718              19.4177
#  Sharpe Ratio                       0.496381              1.15651
#  Sortino Ratio                      0.718338              1.92473
#  Calmar Ratio                       0.953573              1.70533
#  Max. Drawdown [%]                   -7.3771             -13.1686
#  Avg. Drawdown [%]                  -2.66223             -2.16954
#  Max. Drawdown Duration    111 days 00:00:00    195 days 00:00:00
#  Avg. Drawdown Duration     28 days 00:00:00     20 days 00:00:00
#  # Trades                                  3                    6
#  Win Rate [%]                        33.3333              83.3333
#  Best Trade [%]                      11.3994              11.3994
#  Worst Trade [%]                     -3.8137             -3.37886
#  Avg. Trade [%]                      1.16325              3.49773
#  Max. Trade Duration       115 days 00:00:00    115 days 00:00:00
#  Avg. Trade Duration        42 days 00:00:00     45 days 00:00:00
#  Profit Factor                       1.58489              7.47777
#  Expectancy [%]                      1.40229              3.64791
#  SQN                                0.249129              1.41154
#
#                                 ARIMA_Pred_2      ARIMA_Pred_2020  \
#  Start                   2019-03-18 00:00:00  2019-12-31 00:00:00
#  End                     2021-03-16 00:00:00  2020-12-31 00:00:00
#  Duration                  729 days 00:00:00    366 days 00:00:00
#  Exposure Time [%]                   71.0959              69.2098
#  Equity Final [$]                    11758.8              9877.24
#  Equity Peak [$]                     12088.4              10649.1
#  Return [%]                          17.5879              -1.2276
#  Buy & Hold Return [%]               40.7714              16.1623
#  Return (Ann.) [%]                   8.43795             -1.22095
#  Volatility (Ann.) [%]                16.554              18.5059
#  Sharpe Ratio                       0.509722                    0
#  Sortino Ratio                      0.711072                    0
#  Calmar Ratio                       0.434822                    0
#  Max. Drawdown [%]                  -19.4055              -19.066
#  Avg. Drawdown [%]                  -1.81938             -4.39432
#  Max. Drawdown Duration    195 days 00:00:00    191 days 00:00:00
#  Avg. Drawdown Duration     23 days 00:00:00     41 days 00:00:00
#  # Trades                                 16                   12
#  Win Rate [%]                             50              41.6667
#  Best Trade [%]                      11.3994              11.1878
#  Worst Trade [%]                    -3.58717             -11.1856
#  Avg. Trade [%]                      1.02775            -0.115999
#  Max. Trade Duration       149 days 00:00:00    108 days 00:00:00
#  Avg. Trade Duration        32 days 00:00:00     21 days 00:00:00
#  Profit Factor                       2.85117              1.01018
#  Expectancy [%]                      1.10666            0.0168956
#  SQN                                 1.02848           -0.0720297
#
#                              ARIMA_Pred_2019      ARIMA_Pred_2018  \
#  Start                   2018-12-31 00:00:00  2017-12-31 00:00:00
#  End                     2019-12-31 00:00:00  2018-12-31 00:00:00
#  Duration                  365 days 00:00:00    365 days 00:00:00
#  Exposure Time [%]                   60.6557               18.306
#  Equity Final [$]                    11802.4              8704.88
#  Equity Peak [$]                     11889.2              10210.3
#  Return [%]                          18.0242             -12.9512
#  Buy & Hold Return [%]               28.7852             -6.34789
#  Return (Ann.) [%]                   17.9708             -12.9182
#  Volatility (Ann.) [%]               10.5469              8.89375
#  Sharpe Ratio                        1.70389                    0
#  Sortino Ratio                       2.99068                    0
#  Calmar Ratio                        2.72932                    0
#  Max. Drawdown [%]                  -6.58433             -16.8146
#  Avg. Drawdown [%]                 -0.820819             -7.85484
#  Max. Drawdown Duration    163 days 00:00:00    308 days 00:00:00
#  Avg. Drawdown Duration     13 days 00:00:00    109 days 00:00:00
#  # Trades                                  6                    6
#  Win Rate [%]                        66.6667              33.3333
#  Best Trade [%]                      11.3686              1.91718
#  Worst Trade [%]                   -0.528142             -11.3626
#  Avg. Trade [%]                      2.84908             -2.30742
#  Max. Trade Duration       117 days 00:00:00     22 days 00:00:00
#  Avg. Trade Duration        36 days 00:00:00     11 days 00:00:00
#  Profit Factor                       34.3044             0.183245
#  Expectancy [%]                      2.93158             -2.19912
#  SQN                                  1.5555             -1.09977
#
#                              ARIMA_Pred_2017      ARIMA_Pred_2016
#  Start                   2016-12-31 00:00:00  2015-12-31 00:00:00
#  End                     2017-12-31 00:00:00  2016-12-31 00:00:00
#  Duration                  365 days 00:00:00    366 days 00:00:00
#  Exposure Time [%]                   62.2951              60.7629
#  Equity Final [$]                    11377.6              9744.93
#  Equity Peak [$]                     11377.6              10032.9
#  Return [%]                           13.776              -2.5507
#  Buy & Hold Return [%]               19.3844               9.6434
#  Return (Ann.) [%]                   13.7359             -2.53698
#  Volatility (Ann.) [%]               5.81689              9.44594
#  Sharpe Ratio                        2.36138                    0
#  Sortino Ratio                       4.28618                    0
#  Calmar Ratio                        6.66126                    0
#  Max. Drawdown [%]                  -2.06206              -6.4056
#  Avg. Drawdown [%]                 -0.475708             -3.73947
#  Max. Drawdown Duration     35 days 00:00:00    217 days 00:00:00
#  Avg. Drawdown Duration      9 days 00:00:00    120 days 00:00:00
#  # Trades                                  1                    4
#  Win Rate [%]                            100                   75
#  Best Trade [%]                      13.9142             0.777067
#  Worst Trade [%]                     13.9142             -4.31374
#  Avg. Trade [%]                      13.9142            -0.640684
#  Max. Trade Duration       227 days 00:00:00    121 days 00:00:00
#  Avg. Trade Duration       227 days 00:00:00     55 days 00:00:00
#  Profit Factor                           NaN             0.427673
#  Expectancy [%]                      13.9142            -0.617218
#  SQN                                     NaN             -0.52143  ,
#  {'ARIMA_Pred_0.5': (                  Equity  DrawdownPct DrawdownDuration
#    Date
#    2020-09-16  10000.000000     0.000000              NaT
#    2020-09-17  10000.000000     0.000000              NaT
#    2020-09-18  10000.000000     0.000000              NaT
#    2020-09-19   9863.119965     0.013688              NaT
#    2020-09-20   9863.119965     0.013688              NaT
#    ...                  ...          ...              ...
#    2021-03-12  10344.789825     0.007038              NaT
#    2021-03-13  10344.789825     0.007038              NaT
#    2021-03-14  10344.789825     0.007038              NaT
#    2021-03-15  10344.789825     0.007038              NaT
#    2021-03-16  10344.789825     0.007038          29 days
#
#    [182 rows x 3 columns],
#       Size  EntryBar  ExitBar  EntryPrice   ExitPrice          PnL  ReturnPct  \
#    0    29         3       10  335.369995  322.579987  -370.910248  -0.038137
#    1    28        41       44  339.760010  328.279999  -321.440308  -0.033789
#    2    26        52      167  349.929993  389.820007  1037.140381   0.113994
#
#       EntryTime   ExitTime Duration
#    0 2020-09-19 2020-09-26   7 days
#    1 2020-10-27 2020-10-30   3 days
#    2 2020-11-07 2021-03-02 115 days  ),
#   'ARIMA_Pred_1': (                  Equity  DrawdownPct DrawdownDuration
#    Date
#    2020-03-17  10000.000000      0.00000              NaT
#    2020-03-18  10000.000000      0.00000              NaT
#    2020-03-19  10000.000000      0.00000              NaT
#    2020-03-20  10000.000000      0.00000              NaT
#    2020-03-21  10000.000000      0.00000              NaT
#    ...                  ...          ...              ...
#    2021-03-12  12245.678589      0.02944              NaT
#    2021-03-13  12245.678589      0.02944              NaT
#    2021-03-14  12245.678589      0.02944              NaT
#    2021-03-15  12245.678589      0.02944              NaT
#    2021-03-16  12245.678589      0.02944         195 days
#
#    [365 rows x 3 columns],
#       Size  EntryBar  ExitBar  EntryPrice   ExitPrice          PnL  ReturnPct  \
#    0    39        11       13  253.270004  255.699997    94.769714   0.009594
#    1    36        35       37  276.730011  280.489990   135.359253   0.013587
#    2    35        46       81  285.309998  317.230011  1117.200470   0.111878
#    3    35        85      193  321.420013  322.579987    40.599060   0.003609
#    4    33       224      227  339.760010  328.279999  -378.840363  -0.033789
#    2018-01-03  10000.000000     0.000000              NaT
#    2018-01-04  10000.000000     0.000000              NaT
#    ...                  ...          ...              ...
#    2018-12-27   8704.881271     0.147441              NaT
#    2018-12-28   8704.881271     0.147441              NaT
#    2018-12-29   8704.881271     0.147441              NaT
#    2018-12-30   8704.881271     0.147441              NaT
#    2018-12-31   8704.881271     0.147441         308 days
#
#    [366 rows x 3 columns],
#       Size  EntryBar  ExitBar  EntryPrice   ExitPrice          PnL  ReturnPct  \
#    0    35        34       38  280.079987  268.500000  -405.299530  -0.041345
#    1    36        40       62  260.799988  265.799988   180.000000   0.019172
#    2    37        87      101  260.750000  263.470001   100.640045   0.010431
#    3    35       284      286  277.079987  276.769989   -10.849915  -0.001119
#    4    36       298      299  267.380005  265.920013   -52.559692  -0.005460
#    5    35       339      357  278.369995  246.740005 -1107.049637  -0.113626
#
#       EntryTime   ExitTime Duration
#    0 2018-02-03 2018-02-07   4 days
#    1 2018-02-09 2018-03-03  22 days
#    2 2018-03-28 2018-04-11  14 days
#    3 2018-10-11 2018-10-13   2 days
#    4 2018-10-25 2018-10-26   1 days
#    5 2018-12-05 2018-12-23  18 days  ),
#   'ARIMA_Pred_2017': (                  Equity  DrawdownPct DrawdownDuration
#    Date
#    2016-12-31  10000.000000     0.000000              NaT
#    2017-01-01  10000.000000     0.000000              NaT
#    2017-01-02  10000.000000     0.000000              NaT
#    2017-01-03  10000.000000     0.000000              NaT
#    2017-01-04  10000.000000     0.000000              NaT
#    ...                  ...          ...              ...
#    2017-12-27  11326.780487     0.003252              NaT
#    2017-12-28  11349.879974     0.001220              NaT
#    2017-12-29  11307.459564     0.004953              NaT
#    2017-12-30  11307.459564     0.004953              NaT
#    2017-12-31  11377.600128     0.000000          13 days
#
#    [366 rows x 3 columns],
#       Size  EntryBar  ExitBar  EntryPrice   ExitPrice          PnL  ReturnPct  \
#    0    42       138      365  235.729996  268.529999  1377.600128   0.139142
#
#       EntryTime   ExitTime Duration
#    0 2017-05-18 2017-12-31 227 days  ),
#   'ARIMA_Pred_2016': (                  Equity  DrawdownPct DrawdownDuration
#    Date
#    2015-12-31  10000.000000     0.000000              NaT
#    2016-01-01  10000.000000     0.000000              NaT
#    2016-01-02  10000.000000     0.000000              NaT
#    2016-01-03  10000.000000     0.000000              NaT
#    2016-01-04  10000.000000     0.000000              NaT
#    ...                  ...          ...              ...
#    2016-12-27   9744.930115     0.028705              NaT
#    2016-12-28   9744.930115     0.028705              NaT
#    2016-12-29   9744.930115     0.028705              NaT
#    2016-12-30   9744.930115     0.028705              NaT
#    2016-12-31   9744.930115     0.028705         138 days
#
#    [367 rows x 3 columns],
#       Size  EntryBar  ExitBar  EntryPrice   ExitPrice         PnL  ReturnPct  \
#    0    51         8       15  195.190002  186.770004 -429.419907  -0.043137
#    1    46        97      181  204.190002  204.839996   29.899719   0.003183
#    2    45       184      191  209.479996  211.050003   70.650330   0.007495
#    3    45       192      313  211.050003  212.690002   73.799973   0.007771
#
#       EntryTime   ExitTime Duration
#    0 2016-01-08 2016-01-15   7 days
#    1 2016-04-06 2016-06-29  84 days
#    2 2016-07-02 2016-07-09   7 days
#    3 2016-07-10 2016-11-08 121 days  )})
